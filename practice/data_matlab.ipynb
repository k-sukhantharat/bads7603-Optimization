# %%
import scipy.io as sio

# %%
data_mat = sio.loadmat('data/data.mat')

# %%
# check keys
data_mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'A', 'C', 'b', 'd'])

# %%
A = data_mat['A']

# %%
A
# Out:
# array([[ 0.85831464, -0.2551065 ,  0.51555739, -1.52277036,  1.73714667,
#         -0.43151512, -0.64584199,  0.60873364, -1.09170408,  1.42572276],
#        [-0.97989055,  2.6513074 ,  0.41631466, -0.55565268,  0.11221594,
#          0.74852657,  0.77733414,  2.93459723,  0.39691556,  0.28285693],
#        [ 0.3932471 , -1.83568579, -0.40032029, -0.40576637, -0.12576003,
#         -0.49999022, -0.32487547,  0.74289868, -3.91568953,  2.59739069],
#        [ 1.65181621,  0.14003721,  0.60957051, -0.89132317,  1.24088476,
#          1.86991792,  1.75134503, -0.41214326, -0.46844171, -0.51640515],
#        [-1.0299399 ,  1.91744684, -2.36922521, -0.49706111, -0.60300204,
#         -2.24516367,  0.74507619,  2.09418673, -0.60270661, -0.07731738],
#        [ 1.36277463,  0.97517612,  1.83195524,  2.27431051,  1.66157519,
#          0.41999651,  1.39165747, -0.70346487,  0.41189865, -0.04261876],
#        [-1.31794116,  2.18856676, -0.93775929,  0.56325925,  1.89898321,
# ...
